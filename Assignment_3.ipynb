# %% [markdown]
# Visualize the data using R/Python by plotting the graphs for assignment no. 1 and 2. Consider
# suitable data set. Use Scatter plot, Bar plot, Box plot, Pie chart, Line Chart.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/Customers.csv")
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
data.info
# Out:
# <bound method DataFrame.info of       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
data.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
data.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
#fill missing value
data['Annual Income ($)'].fillna(data['Annual Income ($)'].mean(), inplace=True)

data['Profession'].fillna(data['Profession'].mode()[0], inplace=True)
# Out:
# <ipython-input-19-e068c4fb2ced>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Annual Income ($)'].fillna(data['Annual Income ($)'].mean(), inplace=True)
# <ipython-input-19-e068c4fb2ced>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income ($)         0
# Spending Score (1-100)    0
# Profession                0
# Work Experience           0
# Family Size               0
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Gender', y='Spending Score (1-100)', data=data)
plt.title('Spending Score by Gender')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Annual Income ($)', y='Spending Score (1-100)', data=data, hue='Gender', palette='Set1')
plt.xlabel('Annual Income ($)')
plt.ylabel('Spending Score (1-100)')
plt.title('Annual Income vs Spending Score')
plt.show()

# %%
data.shape
# Out:
# (2000, 8)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Profession', y='Spending Score (1-100)', data=data, palette='Set2')
plt.xlabel('Profession')
plt.ylabel('Spending Score (1-100)')
plt.title('Spending Score Distribution by Profession')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-42-d2781632533d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Profession', y='Spending Score (1-100)', data=data, palette='Set2')

# %%
gender_counts = data['Gender'].value_counts()
plt.figure(figsize=(6, 6))
gender_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral'])
plt.title('Gender Distribution')
plt.ylabel('')  # Remove y-label for clarity
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x='Age', y='Spending Score (1-100)', data=data, hue='Gender', palette='Set1')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.title('Age vs Spending Score')
plt.show()
